# %% [markdown]
# # Linear Regression in statsmodels (Practice)

# %% [markdown]
# ## Note: Second phase of the project is at the bottom

# %% [markdown]
# ### Task: Run a linear regression with statsmodels predict the price of a car.
# Note: you will be revisiting this task for a later assignment, so you will want to create a new GitHub repository for your work.
#
# - Dataset Link:  https://www.kaggle.com/datasets/hellbuoy/car-price-prediction
#     - Download and save in repo,
# Steps to Perform:
# - Perform initial preprocessing of data
# - Perform preprocessing for statsmodels
# - Run the model in statsmodels and produce a results summary
# - Evaluate the model on the test set

# %%
#Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.metrics import r2_score, mean_squared_error

## Standard Statsmodels import
import statsmodels.api as sm

# %% [markdown]
# ### Initial data processing

# %%
## load data
file="Data/archive (1)/CarPrice_Assignment.csv"
df = pd.read_csv(file)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %%
## checking for null values
df.isna().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df = df.drop(columns='car_ID')

# %%
# the CarName column added too many columns to the dataset compared to the 
# total number of samples

df = df.drop(columns='CarName')

# %% [markdown]
# ## Checking for assumption of linearity

# %%
plot_kws=dict(line_kws={'color':'red', 'ls':'--'},
             scatter_kws={'edgecolor':'white','lw':1})

# %%
## make num selector and using it to save list of column names
num_select = make_column_selector(dtype_include='number')
num_cols = num_select(df)
num_cols
# Out:
# ['symboling',
#  'wheelbase',
#  'carlength',
#  'carwidth',
#  'carheight',
#  'curbweight',
#  'enginesize',
#  'boreratio',
#  'stroke',
#  'compressionratio',
#  'horsepower',
#  'peakrpm',
#  'citympg',
#  'highwaympg',
#  'price']

# %%
## Making a pairplot with regression lines
sns.pairplot(df, y_vars='price',kind='reg',x_vars=num_cols[:5],
             plot_kws=dict(line_kws={'color':'red', 'ls':'--'},
                           scatter_kws={'edgecolor':'white','lw':1}));

# %%
## Making a pairplot with regression lines
sns.pairplot(df, y_vars='price',kind='reg',x_vars=num_cols[5:10],
             plot_kws=dict(line_kws={'color':'red', 'ls':'--'},
                           scatter_kws={'edgecolor':'white','lw':1}));

# %%
## Making a pairplot with regression lines
sns.pairplot(df, y_vars='price',kind='reg',x_vars=num_cols[10:15],
             plot_kws=dict(line_kws={'color':'red', 'ls':'--'},
                           scatter_kws={'edgecolor':'white','lw':1}));

# %%
# symboling, stroke, compressionratio,and peakrpm don't have a linear relationship with price

df = df.drop(columns=['symboling', 'stroke', 'compressionratio', 'peakrpm'])

# %%
df['ln_citympg'] = np.log(df['citympg'])
df['ln_highwaympg'] = np.log(df['highwaympg'])

# %%
## Making a pairplot with regression lines
sns.pairplot(df, y_vars='price',kind='reg',x_vars=df[{'ln_citympg','ln_highwaympg'}] ,
             plot_kws=dict(line_kws={'color':'red', 'ls':'--'},
                           scatter_kws={'edgecolor':'white','lw':1}));
# Out:
# /var/folders/yt/hk1fgcjn4w16b997bctnz_kr0000gn/T/ipykernel_87586/566280852.py:2: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   sns.pairplot(df, y_vars='price',kind='reg',x_vars=df[{'ln_citympg','ln_highwaympg'}] ,

# %%
df = df.drop(columns=['citympg', 'highwaympg'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   fueltype        205 non-null    object
#  1   aspiration      205 non-null    object
#  2   doornumber      205 non-null    object
#  3   carbody         205 non-null    object
#  4   drivewheel      205 non-null    object
#  5   enginelocation  205 non-null    object
#  6   wheelbase       205 non-null    float64
#  7   carlength       205 non-null    float64
#  8   carwidth        205 non-null    float64
#  9   carheight       205 non-null    float64
#  10  curbweight      205 non-null    int64
#  11  enginetype      205 non-null    object
#  12  cylindernumber  205 non-null    object
#  13  enginesize      205 non-null    int64
#  14  fuelsystem      205 non-null    object
#  15  boreratio       205 non-null    float64
#  16  horsepower      205 non-null    int64
#  17  price           205 non-null    float64
#  18  ln_citympg      205 non-null    float64
#  19  ln_highwaympg   205 non-null    float64
# dtypes: float64(8), int64(3), object(9)
# memory usage: 32.2+ KB

# %% [markdown]
# ## Checking for assumption of no-multicolinearity

# %%
## Calc values of correlations
corr = df.corr().abs()
corr
# Out:
# /var/folders/yt/hk1fgcjn4w16b997bctnz_kr0000gn/T/ipykernel_87586/1696046898.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr().abs()
#                wheelbase  carlength  carwidth  carheight  curbweight  \
# wheelbase       1.000000   0.874587  0.795144   0.589435    0.776386
# carlength       0.874587   1.000000  0.841118   0.491029    0.877728
# carwidth        0.795144   0.841118  1.000000   0.279210    0.867032
# carheight       0.589435   0.491029  0.279210   1.000000    0.295572
# curbweight      0.776386   0.877728  0.867032   0.295572    1.000000
# enginesize      0.569329   0.683360  0.735433   0.067149    0.850594
# boreratio       0.488750   0.606454  0.559150   0.171071    0.648480
# horsepower      0.353294   0.552623  0.640732   0.108802    0.750739
# price           0.577816   0.682920  0.759325   0.119336    0.835305
# ln_citympg      0.476808   0.672877  0.670986   0.023249    0.784800
# ln_highwaympg   0.566749   0.716904  0.710901   0.097920    0.828212
#
#                enginesize  boreratio  horsepower     price  ln_citympg  \
# wheelbase        0.569329   0.488750    0.353294  0.577816    0.476808
# carlength        0.683360   0.606454    0.552623  0.682920    0.672877
# carwidth         0.735433   0.559150    0.640732  0.759325    0.670986
# carheight        0.067149   0.171071    0.108802  0.119336    0.023249
# curbweight       0.850594   0.648480    0.750739  0.835305    0.784800
# enginesize       1.000000   0.583774    0.809769  0.874145    0.705798
# boreratio        0.583774   1.000000    0.573677  0.553173    0.578175
# horsepower       0.809769   0.573677    1.000000  0.808139    0.847835
# price            0.874145   0.553173    0.808139  1.000000    0.746021
# ln_citympg       0.705798   0.578175    0.847835  0.746021    1.000000
# ln_highwaympg    0.732925   0.577906    0.797609  0.752601    0.964736
#
#                ln_highwaympg
# wheelbase           0.566749
# carlength           0.716904
# carwidth            0.710901
# carheight           0.097920
# curbweight          0.828212
# enginesize          0.732925
# boreratio           0.577906
# horsepower          0.797609
# price               0.752601
# ln_citympg          0.964736
# ln_highwaympg       1.000000

# %%
#Create a features dataframe to encode categorical data for correlation
visual_df = df.copy()
objList = visual_df.select_dtypes(include = "object").columns
visual_df[objList] = visual_df[objList].apply(LabelEncoder().fit_transform)

# %%
corr = round(visual_df.corr().abs(),2)
plt.figure(figsize = (20,16));
mask = np.triu(np.ones_like(corr))
sns.heatmap(corr,square=True, cmap='bwr', annot=True, mask=mask);

# %%
# citympg and highwaympg are highly correlated
# carbody and doornumber are highly correlated
# wheelbase, carlength, carwidth, enginesize, curbweight are highly correlated
# horsepower and enginesize are hightly correlated

df = df.drop(columns=['ln_citympg','carbody', 'wheelbase', 'carlength', 'carwidth', 'curbweight', 'enginesize'])

# %%
#Create a features dataframe to encode categorical data for correlation
visual_df = df.copy()
objList = visual_df.select_dtypes(include = "object").columns
visual_df[objList] = visual_df[objList].apply(LabelEncoder().fit_transform)

# %%
corr = round(visual_df.corr().abs(),2)
plt.figure(figsize = (20,16));
mask = np.triu(np.ones_like(corr))
sns.heatmap(corr,square=True, cmap='bwr', annot=True, mask=mask);

# %% [markdown]
# ### Preprocess for statsmodels

# %%
## Make x and y variables
y = df['price'].copy()
X = df.drop(columns=['price']).copy()
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=42)
X_train.head()
# Out:
#     fueltype aspiration doornumber drivewheel enginelocation  carheight  \
# 90    diesel        std        two        fwd          front       54.5
# 173      gas        std       four        fwd          front       54.9
# 93       gas        std       four        fwd          front       53.5
# 5        gas        std        two        fwd          front       53.1
# 167      gas        std        two        rwd          front       52.0
#
#     enginetype cylindernumber fuelsystem  boreratio  horsepower  ln_highwaympg
# 90         ohc           four        idi       2.99          55       3.912023
# 173        ohc           four       mpfi       3.31          92       3.526361
# 93         ohc           four       2bbl       3.15          69       3.610918
# 5          ohc           five       mpfi       3.19         110       3.218876
# 167        ohc           four       mpfi       3.62         116       3.401197

# %%
## make cat selector and using it to save list of column names
cat_select = make_column_selector(dtype_include='object')
cat_cols = cat_select(X_train)
cat_cols
# Out:
# ['fueltype',
#  'aspiration',
#  'doornumber',
#  'drivewheel',
#  'enginelocation',
#  'enginetype',
#  'cylindernumber',
#  'fuelsystem']

# %%
## make num selector and using it to save list of column names
num_select = make_column_selector(dtype_include='number')
num_cols = num_select(X_train)
num_cols
# Out:
# ['carheight', 'boreratio', 'horsepower', 'ln_highwaympg']

# %%
## make pipelines
cat_pipe = make_pipeline(SimpleImputer(strategy='constant',
                                       fill_value='MISSING'),
                         OneHotEncoder(handle_unknown='ignore', sparse=False))
num_pipe = make_pipeline(SimpleImputer(strategy='mean'),#StandardScaler()
                        )
preprocessor = make_column_transformer((cat_pipe,cat_cols),
                                        (num_pipe, num_cols), remainder='passthrough')

# %%
## fit the col transformer
preprocessor.fit(X_train)
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(fill_value='MISSING',
#                                                                 strategy='constant')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False))]),
#                                  ['fueltype', 'aspiration', 'doornumber',
#                                   'drivewheel', 'enginelocation', 'enginetype',
#                                   'cylindernumber', 'fuelsystem']),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer())]),
#                                  ['carheight', 'boreratio', 'horsepower',
#                                   'ln_highwaympg'])])

# %%
# Get feature names

## Create the empty list
final_features = []

# %%
## Finding the categorical pipeline in our col transformer.
preprocessor.named_transformers_['pipeline-1']
# Out:
# Pipeline(steps=[('simpleimputer',
#                  SimpleImputer(fill_value='MISSING', strategy='constant')),
#                 ('onehotencoder',
#                  OneHotEncoder(handle_unknown='ignore', sparse=False))])

# %%
## A) Using named steps dictionary to find the encoder - Part 1
preprocessor.named_transformers_['pipeline-1'].named_steps
# Out:
# {'simpleimputer': SimpleImputer(fill_value='MISSING', strategy='constant'),
#  'onehotencoder': OneHotEncoder(handle_unknown='ignore', sparse=False)}

# %%
## A) Using named steps dictionary to find the encoder - Part 2
ohe_step = preprocessor.named_transformers_['pipeline-1'].named_steps['onehotencoder']

# %%
## Now, get OHE feature names
cat_features = ohe_step.get_feature_names_out(cat_cols)
cat_features
# Out:
# array(['fueltype_diesel', 'fueltype_gas', 'aspiration_std',
#        'aspiration_turbo', 'doornumber_four', 'doornumber_two',
#        'drivewheel_4wd', 'drivewheel_fwd', 'drivewheel_rwd',
#        'enginelocation_front', 'enginelocation_rear', 'enginetype_dohc',
#        'enginetype_dohcv', 'enginetype_l', 'enginetype_ohc',
#        'enginetype_ohcf', 'enginetype_ohcv', 'enginetype_rotor',
#        'cylindernumber_eight', 'cylindernumber_five',
#        'cylindernumber_four', 'cylindernumber_six',
#        'cylindernumber_twelve', 'cylindernumber_two', 'fuelsystem_1bbl',
#        'fuelsystem_2bbl', 'fuelsystem_4bbl', 'fuelsystem_idi',
#        'fuelsystem_mpfi', 'fuelsystem_spdi', 'fuelsystem_spfi'],
#       dtype=object)

# %%
len(cat_features)
# Out:
# 31

# %%
## Add the categorical feature names to our final_features list
final_features.extend(cat_features)
final_features
# Out:
# ['fueltype_diesel',
#  'fueltype_gas',
#  'aspiration_std',
#  'aspiration_turbo',
#  'doornumber_four',
#  'doornumber_two',
#  'drivewheel_4wd',
#  'drivewheel_fwd',
#  'drivewheel_rwd',
#  'enginelocation_front',
#  'enginelocation_rear',
#  'enginetype_dohc',
#  'enginetype_dohcv',
#  'enginetype_l',
#  'enginetype_ohc',
#  'enginetype_ohcf',
#  'enginetype_ohcv',
#  'enginetype_rotor',
#  'cylindernumber_eight',
#  'cylindernumber_five',
#  'cylindernumber_four',
#  'cylindernumber_six',
#  'cylindernumber_twelve',
#  'cylindernumber_two',
#  'fuelsystem_1bbl',
#  'fuelsystem_2bbl',
#  'fuelsystem_4bbl',
#  'fuelsystem_idi',
#  'fuelsystem_mpfi',
#  'fuelsystem_spdi',
#  'fuelsystem_spfi']

# %%
num_cols
# Out:
# ['carheight', 'boreratio', 'horsepower', 'ln_highwaympg']

# %%
## adding the numeric features which were passed through the model
final_features.extend(num_cols)
final_features
# Out:
# ['fueltype_diesel',
#  'fueltype_gas',
#  'aspiration_std',
#  'aspiration_turbo',
#  'doornumber_four',
#  'doornumber_two',
#  'drivewheel_4wd',
#  'drivewheel_fwd',
#  'drivewheel_rwd',
#  'enginelocation_front',
#  'enginelocation_rear',
#  'enginetype_dohc',
#  'enginetype_dohcv',
#  'enginetype_l',
#  'enginetype_ohc',
#  'enginetype_ohcf',
#  'enginetype_ohcv',
#  'enginetype_rotor',
#  'cylindernumber_eight',
#  'cylindernumber_five',
#  'cylindernumber_four',
#  'cylindernumber_six',
#  'cylindernumber_twelve',
#  'cylindernumber_two',
#  'fuelsystem_1bbl',
#  'fuelsystem_2bbl',
#  'fuelsystem_4bbl',
#  'fuelsystem_idi',
#  'fuelsystem_mpfi',
#  'fuelsystem_spdi',
#  'fuelsystem_spfi',
#  'carheight',
#  'boreratio',
#  'horsepower',
#  'ln_highwaympg']

# %%
len(final_features)
# Out:
# 35

# %%
len(y)
# Out:
# 205

# %%
X_train_df = pd.DataFrame( preprocessor.transform(X_train), columns=final_features, index=X_train.index)
X_train_df.head()
# Out:
#      fueltype_diesel  fueltype_gas  aspiration_std  aspiration_turbo  \
# 90               1.0           0.0             1.0               0.0
# 173              0.0           1.0             1.0               0.0
# 93               0.0           1.0             1.0               0.0
# 5                0.0           1.0             1.0               0.0
# 167              0.0           1.0             1.0               0.0
#
#      doornumber_four  doornumber_two  drivewheel_4wd  drivewheel_fwd  \
# 90               0.0             1.0             0.0             1.0
# 173              1.0             0.0             0.0             1.0
# 93               1.0             0.0             0.0             1.0
# 5                0.0             1.0             0.0             1.0
# 167              0.0             1.0             0.0             0.0
#
#      drivewheel_rwd  enginelocation_front  ...  fuelsystem_2bbl  \
# 90              0.0                   1.0  ...              0.0
# 173             0.0                   1.0  ...              0.0
# 93              0.0                   1.0  ...              1.0
# 5               0.0                   1.0  ...              0.0
# 167             1.0                   1.0  ...              0.0
#
#      fuelsystem_4bbl  fuelsystem_idi  fuelsystem_mpfi  fuelsystem_spdi  \
# 90               0.0             1.0              0.0              0.0
# 173              0.0             0.0              1.0              0.0
# 93               0.0             0.0              0.0              0.0
# 5                0.0             0.0              1.0              0.0
# 167              0.0             0.0              1.0              0.0
#
#      fuelsystem_spfi  carheight  boreratio  horsepower  ln_highwaympg
# 90               0.0       54.5       2.99        55.0       3.912023
# 173              0.0       54.9       3.31        92.0       3.526361
# 93               0.0       53.5       3.15        69.0       3.610918
# 5                0.0       53.1       3.19       110.0       3.218876
# 167              0.0       52.0       3.62       116.0       3.401197
#
# [5 rows x 35 columns]

# %%
X_test_df = pd.DataFrame(preprocessor.transform(X_test), columns=final_features, index=X_test.index)
X_test_df.head()
# Out:
#      fueltype_diesel  fueltype_gas  aspiration_std  aspiration_turbo  \
# 15               0.0           1.0             1.0               0.0
# 9                0.0           1.0             0.0               1.0
# 100              0.0           1.0             1.0               0.0
# 132              0.0           1.0             1.0               0.0
# 68               1.0           0.0             0.0               1.0
#
#      doornumber_four  doornumber_two  drivewheel_4wd  drivewheel_fwd  \
# 15               1.0             0.0             0.0             0.0
# 9                0.0             1.0             1.0             0.0
# 100              1.0             0.0             0.0             1.0
# 132              0.0             1.0             0.0             1.0
# 68               1.0             0.0             0.0             0.0
#
#      drivewheel_rwd  enginelocation_front  ...  fuelsystem_2bbl  \
# 15              1.0                   1.0  ...              0.0
# 9               0.0                   1.0  ...              0.0
# 100             0.0                   1.0  ...              1.0
# 132             0.0                   1.0  ...              0.0
# 68              1.0                   1.0  ...              0.0
#
#      fuelsystem_4bbl  fuelsystem_idi  fuelsystem_mpfi  fuelsystem_spdi  \
# 15               0.0             0.0              1.0              0.0
# 9                0.0             0.0              1.0              0.0
# 100              0.0             0.0              0.0              0.0
# 132              0.0             0.0              1.0              0.0
# 68               0.0             1.0              0.0              0.0
#
#      fuelsystem_spfi  carheight  boreratio  horsepower  ln_highwaympg
# 15               0.0       55.7       3.62       182.0       3.091042
# 9                0.0       52.0       3.13       160.0       3.091042
# 100              0.0       54.7       3.33        97.0       3.526361
# 132              0.0       56.1       3.54       110.0       3.332205
# 68               0.0       58.7       3.58       123.0       3.218876
#
# [5 rows x 35 columns]

# %%
## Demo of adding a constant to X_train (not rewriting the df yet-confirming expected results first)
sm.add_constant(X_train_df, prepend=False, has_constant='add').head()
# Out:
#      fueltype_diesel  fueltype_gas  aspiration_std  aspiration_turbo  \
# 90               1.0           0.0             1.0               0.0
# 173              0.0           1.0             1.0               0.0
# 93               0.0           1.0             1.0               0.0
# 5                0.0           1.0             1.0               0.0
# 167              0.0           1.0             1.0               0.0
#
#      doornumber_four  doornumber_two  drivewheel_4wd  drivewheel_fwd  \
# 90               0.0             1.0             0.0             1.0
# 173              1.0             0.0             0.0             1.0
# 93               1.0             0.0             0.0             1.0
# 5                0.0             1.0             0.0             1.0
# 167              0.0             1.0             0.0             0.0
#
#      drivewheel_rwd  enginelocation_front  ...  fuelsystem_4bbl  \
# 90              0.0                   1.0  ...              0.0
# 173             0.0                   1.0  ...              0.0
# 93              0.0                   1.0  ...              0.0
# 5               0.0                   1.0  ...              0.0
# 167             1.0                   1.0  ...              0.0
#
#      fuelsystem_idi  fuelsystem_mpfi  fuelsystem_spdi  fuelsystem_spfi  \
# 90              1.0              0.0              0.0              0.0
# 173             0.0              1.0              0.0              0.0
# 93              0.0              0.0              0.0              0.0
# 5               0.0              1.0              0.0              0.0
# 167             0.0              1.0              0.0              0.0
#
#      carheight  boreratio  horsepower  ln_highwaympg  const
# 90        54.5       2.99        55.0       3.912023    1.0
# 173       54.9       3.31        92.0       3.526361    1.0
# 93        53.5       3.15        69.0       3.610918    1.0
# 5         53.1       3.19       110.0       3.218876    1.0
# 167       52.0       3.62       116.0       3.401197    1.0
#
# [5 rows x 36 columns]

# %%
## Overwrite 
X_train_df = sm.add_constant(X_train_df,has_constant='add', prepend=False)
X_test_df = sm.add_constant(X_test_df,has_constant='add', prepend=False)
display(X_train_df.head(2), X_test_df.head(2))
# Out:
#      fueltype_diesel  fueltype_gas  aspiration_std  aspiration_turbo  \
# 90               1.0           0.0             1.0               0.0
# 173              0.0           1.0             1.0               0.0
#
#      doornumber_four  doornumber_two  drivewheel_4wd  drivewheel_fwd  \
# 90               0.0             1.0             0.0             1.0
# 173              1.0             0.0             0.0             1.0
#
#      drivewheel_rwd  enginelocation_front  ...  fuelsystem_4bbl  \
# 90              0.0                   1.0  ...              0.0
# 173             0.0                   1.0  ...              0.0
#
#      fuelsystem_idi  fuelsystem_mpfi  fuelsystem_spdi  fuelsystem_spfi  \
# 90              1.0              0.0              0.0              0.0
# 173             0.0              1.0              0.0              0.0
#
#      carheight  boreratio  horsepower  ln_highwaympg  const
# 90        54.5       2.99        55.0       3.912023    1.0
# 173       54.9       3.31        92.0       3.526361    1.0
#
# [2 rows x 36 columns]
#     fueltype_diesel  fueltype_gas  aspiration_std  aspiration_turbo  \
# 15              0.0           1.0             1.0               0.0
# 9               0.0           1.0             0.0               1.0
#
#     doornumber_four  doornumber_two  drivewheel_4wd  drivewheel_fwd  \
# 15              1.0             0.0             0.0             0.0
# 9               0.0             1.0             1.0             0.0
#
#     drivewheel_rwd  enginelocation_front  ...  fuelsystem_4bbl  \
# 15             1.0                   1.0  ...              0.0
# 9              0.0                   1.0  ...              0.0
#
#     fuelsystem_idi  fuelsystem_mpfi  fuelsystem_spdi  fuelsystem_spfi  \
# 15             0.0              1.0              0.0              0.0
# 9              0.0              1.0              0.0              0.0
#
#     carheight  boreratio  horsepower  ln_highwaympg  const
# 15       55.7       3.62       182.0       3.091042    1.0
# 9        52.0       3.13       160.0       3.091042    1.0
#
# [2 rows x 36 columns]

# %%
drop_columns = ['fueltype_gas',
                'aspiration_std',
                'aspiration_turbo',
                'doornumber_four',   
                'doornumber_two',
                'drivewheel_4wd',
                'drivewheel_fwd',
                'drivewheel_rwd',
                'enginelocation_front',
                'cylindernumber_eight',
                'cylindernumber_five',
                'cylindernumber_four',
                'cylindernumber_six',
                'cylindernumber_twelve',
                'cylindernumber_two',
                'fuelsystem_1bbl',
                'fuelsystem_2bbl',
                'fuelsystem_4bbl',
                'fuelsystem_idi',
                'fuelsystem_mpfi',
                'fuelsystem_spdi',
                'fuelsystem_spfi',
                'carheight',
                'boreratio'
               ]
X_train_df = X_train_df.drop(columns=drop_columns)
X_test_df = X_test_df.drop(columns=drop_columns)

# %% [markdown]
# ### Run the model in statsmodels and produce a results summary

# %%
model = sm.OLS(y_train, X_train_df, hasconst=True)

# %%
# Fitting the model (no data in .fit) and saving the result as new var
result = model.fit()

# %%
## get model performance metrics
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.809
# Model:                            OLS   Adj. R-squared:                  0.795
# Method:                 Least Squares   F-statistic:                     59.97
# Date:                Thu, 19 Jan 2023   Prob (F-statistic):           5.61e-46
# Time:                        18:32:43   Log-Likelihood:                -1463.3
# No. Observations:                 153   AIC:                             2949.
# Df Residuals:                     142   BIC:                             2982.
# Df Model:                          10
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# fueltype_diesel      6611.7035   1140.248      5.798      0.000    4357.649    8865.758
# enginelocation_rear  1.509e+04   3143.082      4.802      0.000    8880.845    2.13e+04
# enginetype_dohc      9710.5786   1753.060      5.539      0.000    6245.111    1.32e+04
# enginetype_dohcv     1.719e+04   5335.962      3.221      0.002    6638.614    2.77e+04
# enginetype_l         7530.7991   1479.276      5.091      0.000    4606.549    1.05e+04
# enginetype_ohc       1.079e+04   1495.719      7.211      0.000    7829.424    1.37e+04
# enginetype_ohcf      7509.0338   1716.705      4.374      0.000    4115.432    1.09e+04
# enginetype_ohcv      1.147e+04   1839.361      6.236      0.000    7834.582    1.51e+04
# enginetype_rotor     5528.0163   1999.758      2.764      0.006    1574.873    9481.160
# horsepower             58.6574     18.989      3.089      0.002      21.120      96.194
# ln_highwaympg       -2.173e+04   2917.776     -7.447      0.000   -2.75e+04    -1.6e+04
# const                6.972e+04   1.03e+04      6.750      0.000    4.93e+04    9.01e+04
# ==============================================================================
# Omnibus:                       19.813   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.723
# Skew:                           0.711   Prob(JB):                     5.79e-07
# Kurtosis:                       4.576   Cond. No.                     1.80e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.05e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# ### Evaluate the model on the train set

# %% [markdown]
# The r-squared is a solid .91 which indicates a good fit.  The adj. R-squared drops to .89 indicating that we have a reasonable number of features for the given number of data points.

# %% [markdown]
# ### Evaluate the model on the test set

# %%
## Fit an OLS model
model = sm.OLS(y_train,X_train_df)
result = model.fit()
## Use the result (not the model) to .predict
test_preds = result.predict(X_test_df)

# %%
# e.g. r2_score, mean_squared_error
test_r2 = r2_score(y_test, test_preds)
test_mse = mean_squared_error(y_test, test_preds)

# Now that we have saved our metrics, we will want to report the scores in a clean, easy-to-read print statement. We can use f-strings to do this!

print(f'The testing r-square value is {test_r2} and the testing mean squared error is {test_mse}.')
# Out:
# The testing r-square value is 0.6695861325998421 and the testing mean squared error is 22355649.247503094.

# %% [markdown]
# As you can see, the test r-squared value is way better than the first regression!

# %% [markdown]
# # Diagnosing Your Regression Model (Practice)

# %% [markdown]
# - Now that you've learned about the assumptions of Linear Regression and how to check them, revisit your model from the Linear Regression in statsmodles assignment and test if your regression meets the assumption.
#     - In a markdown cell below your results, summarize what assumptions the model did and/or did not meet.
# - If you model did not meet the assumptions, then iterate on the model and add/change any preprocessing needed to improve its performance.
#
# Submit your GitHub respitory link with your work.

# %% [markdown]
# # Checking assumptions of linear regression

# %% [markdown]
# ## Assumption of normality

# %%
# To get our residuals from statsmodels and preview first 5
resid = result.resid
resid.head()
# Out:
# 90     1752.799621
# 173    -336.439990
# 93     1250.930340
# 5     -1771.257400
# 167   -4962.743905
# dtype: float64

# %%
sm.graphics.qqplot(resid,line='45',fit=True);

# %% [markdown]
# Looks pretty 'normal'

# %% [markdown]
# ## Assumption of homoscedasticity

# %%
## Get predictions and calculate residuals
y_pred = result.predict(X_train_df)
resid = y_train -  y_pred
## Plot predicitons vs resids
fig, ax = plt.subplots()
ax.scatter(y_pred,resid,ec='white',lw=1)
ax.axhline(0)
ax.set(ylabel='Residuals',xlabel='Predicted Value');

# %%
def evaluate_ols(result,X_train_df, y_train):
    """Plots a Q-Q Plot and residual plot for a statsmodels OLS regression.
    """
    
    ## save residuals from result
    y_pred = result.predict(X_train_df)
    resid = y_train - y_pred
    
    fig, axes = plt.subplots(ncols=2,figsize=(12,5))
    
    ## Normality 
    sm.graphics.qqplot(resid,line='45',fit=True,ax=axes[0]);
    
    ## Homoscedasticity
    ax = axes[1]
    ax.scatter(y_pred, resid, edgecolor='white',lw=1)
    ax.axhline(0,zorder=0)
    ax.set(ylabel='Residuals',xlabel='Predicted Value');
    plt.tight_layout()
    
evaluate_ols(result,X_train_df, y_train)

# %% [markdown]
# ## Normality and homoscedasticity looks reasonable!

# %% [markdown]
# ## Remove columns with insignificant P-Values

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.809
# Model:                            OLS   Adj. R-squared:                  0.795
# Method:                 Least Squares   F-statistic:                     59.97
# Date:                Thu, 19 Jan 2023   Prob (F-statistic):           5.61e-46
# Time:                        18:32:43   Log-Likelihood:                -1463.3
# No. Observations:                 153   AIC:                             2949.
# Df Residuals:                     142   BIC:                             2982.
# Df Model:                          10
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# fueltype_diesel      6611.7035   1140.248      5.798      0.000    4357.649    8865.758
# enginelocation_rear  1.509e+04   3143.082      4.802      0.000    8880.845    2.13e+04
# enginetype_dohc      9710.5786   1753.060      5.539      0.000    6245.111    1.32e+04
# enginetype_dohcv     1.719e+04   5335.962      3.221      0.002    6638.614    2.77e+04
# enginetype_l         7530.7991   1479.276      5.091      0.000    4606.549    1.05e+04
# enginetype_ohc       1.079e+04   1495.719      7.211      0.000    7829.424    1.37e+04
# enginetype_ohcf      7509.0338   1716.705      4.374      0.000    4115.432    1.09e+04
# enginetype_ohcv      1.147e+04   1839.361      6.236      0.000    7834.582    1.51e+04
# enginetype_rotor     5528.0163   1999.758      2.764      0.006    1574.873    9481.160
# horsepower             58.6574     18.989      3.089      0.002      21.120      96.194
# ln_highwaympg       -2.173e+04   2917.776     -7.447      0.000   -2.75e+04    -1.6e+04
# const                6.972e+04   1.03e+04      6.750      0.000    4.93e+04    9.01e+04
# ==============================================================================
# Omnibus:                       19.813   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.723
# Skew:                           0.711   Prob(JB):                     5.79e-07
# Kurtosis:                       4.576   Cond. No.                     1.80e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.05e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
## save p-values
p_vals = result.pvalues
## filter for p_values that are >.05
p_vals[p_vals>.05]
# Out:
# Series([], dtype: float64)

# %%
# use a list comprehension to filter out column sthat start with zipcode
fueltype_cols = [col for col in X_train_df.columns if col.startswith('fueltype')]
## preview first few zipcode cols to confirm
fueltype_cols[:3]
# Out:
# ['fueltype_diesel']

# %%
len(fueltype_cols)
# Out:
# 1

# %% [markdown]
# Columns with low p-values removed before running model

# %%
X_train_df
# Out:
#      fueltype_diesel  enginelocation_rear  enginetype_dohc  enginetype_dohcv  \
# 90               1.0                  0.0              0.0               0.0
# 173              0.0                  0.0              0.0               0.0
# 93               0.0                  0.0              0.0               0.0
# 5                0.0                  0.0              0.0               0.0
# 167              0.0                  0.0              0.0               0.0
# ..               ...                  ...              ...               ...
# 106              0.0                  0.0              0.0               0.0
# 14               0.0                  0.0              0.0               0.0
# 92               0.0                  0.0              0.0               0.0
# 179              0.0                  0.0              1.0               0.0
# 102              0.0                  0.0              0.0               0.0
#
#      enginetype_l  enginetype_ohc  enginetype_ohcf  enginetype_ohcv  \
# 90            0.0             1.0              0.0              0.0
# 173           0.0             1.0              0.0              0.0
# 93            0.0             1.0              0.0              0.0
# 5             0.0             1.0              0.0              0.0
# 167           0.0             1.0              0.0              0.0
# ..            ...             ...              ...              ...
# 106           0.0             0.0              0.0              1.0
# 14            0.0             1.0              0.0              0.0
# 92            0.0             1.0              0.0              0.0
# 179           0.0             0.0              0.0              0.0
# 102           0.0             0.0              0.0              1.0
#
#      enginetype_rotor  horsepower  ln_highwaympg  const
# 90                0.0        55.0       3.912023    1.0
# 173               0.0        92.0       3.526361    1.0
# 93                0.0        69.0       3.610918    1.0
# 5                 0.0       110.0       3.218876    1.0
# 167               0.0       116.0       3.401197    1.0
# ..                ...         ...            ...    ...
# 106               0.0       160.0       3.218876    1.0
# 14                0.0       121.0       3.218876    1.0
# 92                0.0        69.0       3.610918    1.0
# 179               0.0       161.0       3.178054    1.0
# 102               0.0       152.0       3.091042    1.0
#
# [153 rows x 12 columns]

# %%
# Saving model or later

export = {'X_train':X_train,
         'y_train':y_train,
         'X_test':X_test,
         'y_test':y_test,
          'Column Transformer':preprocessor,
         'OLS Results': result}

# %%
import joblib
joblib.dump(export, 'ols_results.joblib')
# Out:
# ['ols_results.joblib']
